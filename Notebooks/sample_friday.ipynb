# %%
import polars as pl

file = r"D:/Dissertation 2025/Results/Friday_clean.csv"

# Load SMALL sample 
sample_df = pl.read_csv(
    file,
    n_rows=30000,             
    infer_schema_length=0,    
    ignore_errors=True
)

print("Sample shape:", sample_df.shape)
print("Columns loaded:", len(sample_df.columns))
# Out:
# Sample shape: (30000, 81)
# Columns loaded: 81

# %%
label_cols = {"Label", "y_binary", "y_family", "day"}

numeric_df = sample_df.with_columns([
    pl.col(col).cast(pl.Float64, strict=False)
    for col in sample_df.columns
    if col not in label_cols
])

print("Numeric DF shape:", numeric_df.shape)
# Out:
# Numeric DF shape: (30000, 81)

# %%
# Select numeric columns only
num_cols = [c for c in numeric_df.columns if c not in label_cols]

# Convert Polars → pandas safely
df_dict = numeric_df.select(num_cols).to_dict(as_series=True)

import pandas as pd
corr_df = pd.DataFrame(df_dict)

# Correlation matrix
corr_matrix = corr_df.corr()

print("\nCorrelation matrix:")
print(corr_matrix)
# Out:
# Correlation matrix:
#                                Flow Duration   Total Fwd Packets  \
#  Flow Duration                      1.000000            0.307298
#  Total Fwd Packets                  0.307298            1.000000
#  Total Backward Packets             0.243719            0.975712
# Total Length of Fwd Packets         0.225467            0.293829
#  Total Length of Bwd Packets        0.167233            0.957829
# ...                                      ...                 ...
#  Active Min                         0.115810            0.144508
# Idle Mean                           0.651558            0.168449
#  Idle Std                           0.169020            0.063118
#  Idle Max                           0.655198            0.172893
#  Idle Min                           0.630911            0.160136
#
#                                Total Backward Packets  \
#  Flow Duration                               0.243719
#  Total Fwd Packets                           0.975712
#  Total Backward Packets                      1.000000
# Total Length of Fwd Packets                  0.252112
#  Total Length of Bwd Packets                 0.984171
# ...                                               ...
#  Active Min                                  0.138605
# Idle Mean                                    0.144791
#  Idle Std                                    0.045171
#  Idle Max                                    0.146830
#  Idle Min                                    0.139067
#
#                               Total Length of Fwd Packets  \
#  Flow Duration                                   0.225467
#  Total Fwd Packets                               0.293829
#  Total Backward Packets                          0.252112
# Total Length of Fwd Packets                      1.000000
#  Total Length of Bwd Packets                     0.173100
# ...                                                   ...
#  Active Min                                      0.111926
# Idle Mean                                        0.096933
#  Idle Std                                        0.073336
#  Idle Max                                        0.104695
#  Idle Min                                        0.086508
#
#                                Total Length of Bwd Packets  \
#  Flow Duration                                    0.167233
#  Total Fwd Packets                                0.957829
#  Total Backward Packets                           0.984171
# Total Length of Fwd Packets                       0.173100
#  Total Length of Bwd Packets                      1.000000
# ...                                                    ...
#  Active Min                                       0.114485
# Idle Mean                                         0.102582
#  Idle Std                                         0.027035
#  Idle Max                                         0.103468
#  Idle Min                                         0.099383
#
#                                Fwd Packet Length Max   Fwd Packet Length Min  \
#  Flow Duration                              0.309328               -0.197286
#  Total Fwd Packets                          0.158437               -0.089566
#  Total Backward Packets                     0.135988               -0.067270
# Total Length of Fwd Packets                 0.564682               -0.076729
#  Total Length of Bwd Packets                0.075390               -0.044805
# ...                                              ...                     ...
#  Active Min                                 0.104900               -0.071657
# Idle Mean                                   0.138726               -0.074695
#  Idle Std                                   0.053826               -0.017284
#  Idle Max                                   0.142092               -0.074876
#  Idle Min                                   0.130516               -0.071467
#
#                                Fwd Packet Length Mean   Fwd Packet Length Std  \
#  Flow Duration                               0.079875                0.197514
#  Total Fwd Packets                           0.037751                0.079370
#  Total Backward Packets                      0.029038                0.064735
# Total Length of Fwd Packets                  0.475018                0.445149
#  Total Length of Bwd Packets                -0.005561                0.020044
# ...                                               ...                     ...
#  Active Min                                  0.052091                0.077212
# Idle Mean                                    0.035251                0.080556
#  Idle Std                                    0.019056                0.031374
#  Idle Max                                    0.037033                0.082701
#  Idle Min                                    0.032479                0.075639
#
#                               Bwd Packet Length Max  ...   act_data_pkt_fwd  \
#  Flow Duration                             0.536274  ...           0.269839
#  Total Fwd Packets                         0.423670  ...           0.820061
#  Total Backward Packets                    0.383963  ...           0.770901
# Total Length of Fwd Packets                0.260053  ...           0.303074
#  Total Length of Bwd Packets               0.329916  ...           0.729745
# ...                                             ...  ...                ...
#  Active Min                                0.199962  ...           0.124218
# Idle Mean                                  0.314925  ...           0.161969
#  Idle Std                                  0.063392  ...           0.061053
#  Idle Max                                  0.313974  ...           0.165837
#  Idle Min                                  0.305840  ...           0.154781
#
#                                min_seg_size_forward  Active Mean   Active Std  \
#  Flow Duration                            -0.077859     0.262322     0.397421
#  Total Fwd Packets                        -0.028123     0.266539     0.325078
#  Total Backward Packets                   -0.010110     0.203675     0.235672
# Total Length of Fwd Packets               -0.010427     0.388731     0.461137
#  Total Length of Bwd Packets              -0.004742     0.151215     0.174374
# ...                                             ...          ...          ...
#  Active Min                               -0.006313     0.795962     0.030625
# Idle Mean                                 -0.069595     0.226289     0.141453
#  Idle Std                                 -0.029570     0.112736     0.117090
#  Idle Max                                 -0.072110     0.237834     0.154898
#  Idle Min                                 -0.067036     0.214565     0.125865
#
#                                Active Max   Active Min  Idle Mean   Idle Std  \
#  Flow Duration                   0.427701     0.115810   0.651558   0.169020
#  Total Fwd Packets               0.360404     0.144508   0.168449   0.063118
#  Total Backward Packets          0.274382     0.138605   0.144791   0.045171
# Total Length of Fwd Packets      0.450918     0.111926   0.096933   0.073336
#  Total Length of Bwd Packets     0.212188     0.114485   0.102582   0.027035
# ...                                   ...          ...        ...        ...
#  Active Min                      0.370336     1.000000   0.200875   0.049180
# Idle Mean                        0.175692     0.200875   1.000000   0.148505
#  Idle Std                        0.107472     0.049180   0.148505   1.000000
#  Idle Max                        0.187434     0.203344   0.994457   0.247807
#  Idle Min                        0.160656     0.197607   0.994788   0.051376
#
#                                Idle Max   Idle Min
#  Flow Duration                 0.655198   0.630911
#  Total Fwd Packets             0.172893   0.160136
#  Total Backward Packets        0.146830   0.139067
# Total Length of Fwd Packets    0.104695   0.086508
#  Total Length of Bwd Packets   0.103468   0.099383
# ...                                 ...        ...
#  Active Min                    0.203344   0.197607
# Idle Mean                      0.994457   0.994788
#  Idle Std                      0.247807   0.051376
#  Idle Max                      1.000000   0.979538
#  Idle Min                      0.979538   1.000000
#
# [77 rows x 77 columns]

# %%
# Mutual Information
from sklearn.feature_selection import mutual_info_classif
import pandas as pd
import numpy as np

# Convert Polars → pandas safely
df_dict = numeric_df.select(num_cols).to_dict(as_series=True)
X = pd.DataFrame(df_dict)

# Target
y = numeric_df["y_binary"].to_pandas()

# CLEAN X 
X = X.replace([np.inf, -np.inf], np.nan)  # remove inf
X = X.clip(lower=-1e10, upper=1e10)       # clip extreme values
X = X.fillna(0)                           # final fill

# Compute MI
mi_scores = mutual_info_classif(X, y, discrete_features=False)

# Sorted MI values
mi_series = pd.Series(mi_scores, index=X.columns).sort_values(ascending=False)

print("\nTop 20 MI features:\n", mi_series.head(20))
# Out:
# Top 20 MI features:
#   min_seg_size_forward          0.004230
#  Down/Up Ratio                 0.002988
#  Init_Win_bytes_backward       0.001708
# Init_Win_bytes_forward         0.001587
#  ACK Flag Count                0.001541
#  Total Backward Packets        0.001368
#  PSH Flag Count                0.001261
#  Fwd Packet Length Min         0.000416
#  Flow Duration                 0.000373
# Flow Bytes/s                   0.000351
#  Min Packet Length             0.000329
#  URG Flag Count                0.000270
#  Bwd Packet Length Min         0.000252
# Total Length of Fwd Packets    0.000223
#  Packet Length Mean            0.000218
#  Average Packet Size           0.000210
#  Max Packet Length             0.000190
#  Avg Fwd Segment Size          0.000190
#  Fwd Packet Length Mean        0.000175
#  Flow IAT Max                  0.000173
# dtype: float64
